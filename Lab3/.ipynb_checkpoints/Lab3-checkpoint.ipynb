# %%
import tweepy
from tweepy import OAuthHandler
 
consumer_key = 'MzbNY4ZTseRISzT1fOanBPBGK'
consumer_secret = 'b9HYlB2mclNgun3KjLHcRXMSf2M1oXYEWmKiNvwdvtxysEwGPr'
access_token = '307995792-c99yqJojiA8YdoaIPZMJhZJJJ0Rn1a0I3euwm6iH'
access_secret = '0dsQUDQ9JSzgfyB5qoEtOZYe3BVvnl2JfZSZh5CthBvxd'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
 
class MyListener(StreamListener):
 
    def on_data(self, data):
        try:
            with open('ArtificialIntelligenceTweets.json', 'a') as f:
                f.write(data)
                return True
        except BaseException as e:
            print("Error on_data: %s" % str(e))
        return True
 
    def on_error(self, status):
        print(status)
        return True
 
twitter_stream = Stream(auth, MyListener())
twitter_stream.filter(track=['ArtificialIntelligence'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-bdf1e3c198a3> in <module>()
#      18
#      19 twitter_stream = Stream(auth, MyListener())
# ---> 20 twitter_stream.filter(track=['ArtificialIntelligence'])
#
# /home/chetan/anaconda2/lib/python2.7/site-packages/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /home/chetan/anaconda2/lib/python2.7/site-packages/tweepy/streaming.pyc in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /home/chetan/anaconda2/lib/python2.7/site-packages/tweepy/streaming.pyc in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /home/chetan/anaconda2/lib/python2.7/site-packages/tweepy/streaming.pyc in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /home/chetan/anaconda2/lib/python2.7/site-packages/tweepy/streaming.pyc in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# /home/chetan/.local/lib/python2.7/site-packages/requests/packages/urllib3/response.pyc in read(self, amt, decode_content, cache_content)
#     378             else:
#     379                 cache_content = False
# --> 380                 data = self._fp.read(amt)
#     381                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     382                     # Close the connection when no data is returned
#
# /home/chetan/anaconda2/lib/python2.7/httplib.pyc in read(self, amt)
#     571
#     572         if self.chunked:
# --> 573             return self._read_chunked(amt)
#     574
#     575         if amt is None:
#
# /home/chetan/anaconda2/lib/python2.7/httplib.pyc in _read_chunked(self, amt)
#     613         while True:
#     614             if chunk_left is None:
# --> 615                 line = self.fp.readline(_MAXLINE + 1)
#     616                 if len(line) > _MAXLINE:
#     617                     raise LineTooLong("chunk size")
#
# /home/chetan/anaconda2/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /home/chetan/.local/lib/python2.7/site-packages/requests/packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     265                 raise
#     266         except OpenSSL.SSL.WantReadError:
# --> 267             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     268             if not rd:
#     269                 raise timeout('The read operation timed out')
#
# /home/chetan/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/wait.pyc in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# /home/chetan/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/wait.pyc in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# /home/chetan/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/selectors.pyc in select(self, timeout)
#     406             fd_events = _syscall_wrapper(self._epoll.poll, True,
#     407                                          timeout=timeout,
# --> 408                                          maxevents=max_events)
#     409             for fd, event_mask in fd_events:
#     410                 events = 0
#
# /home/chetan/.local/lib/python2.7/site-packages/requests/packages/urllib3/util/selectors.pyc in _syscall_wrapper(func, recalc_timeout, *args, **kwargs)
#      74     while result is _SYSCALL_SENTINEL:
#      75         try:
# ---> 76             result = func(*args, **kwargs)
#      77         # OSError is thrown by select.select
#      78         # IOError is thrown by select.epoll.poll
#
# KeyboardInterrupt:

# %%
import json  
with open('ArtificialIntelligenceTweets.json','r') as json_file:
         for line in json_file:
             tweet = json.loads(line)
             print tweet["text"]
# Out:
# RT @InvestorIdeas: #ArtificialIntelligence #Stock @breakingdataco  $BKD.V; $BKDCD Records 436%+ Across #GIVEMESPORT Key ( $FB) Metrics…
# RT @IBMItalia: Al #WatsonSummit2017 @RICOHItalia ci mostrerà come l'#ArtificialIntelligence può trasformare i meeting aziendali  https://t.…
# How media agency #Maxus is testing #ArtificialIntelligence . #machinelearning #deeplearning  https://t.co/fQHoDtMnXb
# Brazils #banks turn to #AI eye blockchain https://t.co/tXn2LSvYBi #Blockchain #Tech #TechNews #ArtificialIntelligence #BankTech #Brazil
# #Artificialintelligence emerging as a force for good https://t.co/RrPCrkDZEL
# RT @InvestorIdeas: #Technology #Stocks: #ArtificialIntelligence - Opportunity &amp; #Market; ( $EA), ( $GOOGL), ( $GOPH), ( $FB), ( $IBM)
# http…

# %%
import json
 
with open('ArtificialIntelligenceTweets.json', 'r') as f:
    line = f.readline() 
    tweet = json.loads(line) 
    print(json.dumps(tweet, indent=4))
# Out:
# {
#     "contributors": null,
#     "truncated": false,
#     "text": "RT @InvestorIdeas: #ArtificialIntelligence #Stock @breakingdataco  $BKD.V; $BKDCD Records 436%+ Across #GIVEMESPORT Key ( $FB) Metrics\u2026 ",
#     "is_quote_status": false,
#     "in_reply_to_status_id": null,
#     "id": 862994783005949952,
#     "favorite_count": 0,
#     "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#     "retweeted": false,
#     "coordinates": null,
#     "timestamp_ms": "1494588964593",
#     "entities": {
#         "user_mentions": [
#             {
#                 "id": 16145086,
#                 "indices": [
#                     3,
#                     17
#                 ],
#                 "id_str": "16145086",
#                 "screen_name": "InvestorIdeas",
#                 "name": "InvestorIdeas.com"
#             },
#             {
#                 "id": 4796745148,
#                 "indices": [
#                     50,
#                     65
#                 ],
#                 "id_str": "4796745148",
#                 "screen_name": "breakingdataco",
#                 "name": "Breaking Data Corp."
#             }
#         ],
#         "symbols": [
#             {
#                 "indices": [
#                     67,
#                     73
#                 ],
#                 "text": "BKD.V"
#             },
#             {
#                 "indices": [
#                     75,
#                     81
#                 ],
#                 "text": "BKDCD"
#             },
#             {
#                 "indices": [
#                     122,
#                     125
#                 ],
#                 "text": "FB"
#             }
#         ],
#         "hashtags": [
#             {
#                 "indices": [
#                     19,
#                     42
#                 ],
#                 "text": "ArtificialIntelligence"
#             },
#             {
#                 "indices": [
#                     43,
#                     49
#                 ],
#                 "text": "Stock"
#             },
#             {
#                 "indices": [
#                     103,
#                     115
#                 ],
#                 "text": "GIVEMESPORT"
#             }
#         ],
#         "urls": [
#             {
#                 "url": "",
#                 "indices": [
#                     136,
#                     136
#                 ],
#                 "expanded_url": null
#             }
#         ]
#     },
#     "in_reply_to_screen_name": null,
#     "id_str": "862994783005949952",
#     "retweet_count": 0,
#     "in_reply_to_user_id": null,
#     "favorited": false,
#     "retweeted_status": {
#         "contributors": null,
#         "truncated": true,
#         "text": "#ArtificialIntelligence #Stock @breakingdataco  $BKD.V; $BKDCD Records 436%+ Across #GIVEMESPORT Key ( $FB) Metrics\u2026 https://t.co/ZrNJsDgPPO",
#         "is_quote_status": false,
#         "in_reply_to_status_id": null,
#         "id": 862819723318317056,
#         "favorite_count": 10,
#         "source": "<a href=\"http://www.hootsuite.com\" rel=\"nofollow\">Hootsuite</a>",
#         "retweeted": false,
#         "coordinates": null,
#         "entities": {
#             "user_mentions": [
#                 {
#                     "id": 4796745148,
#                     "indices": [
#                         31,
#                         46
#                     ],
#                     "id_str": "4796745148",
#                     "screen_name": "breakingdataco",
#                     "name": "Breaking Data Corp."
#                 }
#             ],
#             "symbols": [
#                 {
#                     "indices": [
#                         48,
#                         54
#                     ],
#                     "text": "BKD.V"
#                 },
#                 {
#                     "indices": [
#                         56,
#                         62
#                     ],
#                     "text": "BKDCD"
#                 },
#                 {
#                     "indices": [
#                         103,
#                         106
#                     ],
#                     "text": "FB"
#                 }
#             ],
#             "hashtags": [
#                 {
#                     "indices": [
#                         0,
#                         23
#                     ],
#                     "text": "ArtificialIntelligence"
#                 },
#                 {
#                     "indices": [
#                         24,
#                         30
#                     ],
#                     "text": "Stock"
#                 },
#                 {
#                     "indices": [
#                         84,
#                         96
#                     ],
#                     "text": "GIVEMESPORT"
#                 }
#             ],
#             "urls": [
#                 {
#                     "url": "https://t.co/ZrNJsDgPPO",
#                     "indices": [
#                         117,
#                         140
#                     ],
#                     "expanded_url": "https://twitter.com/i/web/status/862819723318317056",
#                     "display_url": "twitter.com/i/web/status/8\u2026"
#                 }
#             ]
#         },
#         "in_reply_to_screen_name": null,
#         "id_str": "862819723318317056",
#         "display_text_range": [
#             0,
#             140
#         ],
#         "retweet_count": 69,
#         "in_reply_to_user_id": null,
#         "favorited": false,
#         "user": {
#             "follow_request_sent": null,
#             "profile_use_background_image": true,
#             "default_profile_image": false,
#             "id": 16145086,
#             "verified": false,
#             "profile_image_url_https": "https://pbs.twimg.com/profile_images/601434755289067520/5YJnF56a_normal.png",
#             "profile_sidebar_fill_color": "C7C7C7",
#             "profile_text_color": "000000",
#             "followers_count": 215404,
#             "profile_sidebar_border_color": "787778",
#             "id_str": "16145086",
#             "profile_background_color": "070063",
#             "listed_count": 739,
#             "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/601426742524260352/IqM7p2IM.png",
#             "utc_offset": -25200,
#             "statuses_count": 40348,
#             "description": "Investing news for #tech , #Bitcoin, #biotech, #mining, water, #cannabis stocks, #wine,  #defense stocks, #sports on TSX,  OTC, NASDAQ, NYSE See Disclaimers",
#             "friends_count": 5953,
#             "location": "Global ",
#             "profile_link_color": "0048FF",
#             "profile_image_url": "http://pbs.twimg.com/profile_images/601434755289067520/5YJnF56a_normal.png",
#             "following": null,
#             "geo_enabled": false,
#             "profile_banner_url": "https://pbs.twimg.com/profile_banners/16145086/1490975859",
#             "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/601426742524260352/IqM7p2IM.png",
#             "name": "InvestorIdeas.com",
#             "lang": "en",
#             "profile_background_tile": false,
#             "favourites_count": 55,
#             "screen_name": "InvestorIdeas",
#             "notifications": null,
#             "url": "http://www.investorideas.com",
#             "created_at": "Fri Sep 05 15:38:59 +0000 2008",
#             "contributors_enabled": false,
#             "time_zone": "Pacific Time (US & Canada)",
#             "protected": false,
#             "default_profile": false,
#             "is_translator": false
#         },
#         "geo": null,
#         "in_reply_to_user_id_str": null,
#         "possibly_sensitive": false,
#         "lang": "en",
#         "extended_tweet": {
#             "display_text_range": [
#                 0,
#                 139
#             ],
#             "entities": {
#                 "user_mentions": [
#                     {
#                         "id": 4796745148,
#                         "indices": [
#                             31,
#                             46
#                         ],
#                         "id_str": "4796745148",
#                         "screen_name": "breakingdataco",
#                         "name": "Breaking Data Corp."
#                     }
#                 ],
#                 "symbols": [
#                     {
#                         "indices": [
#                             48,
#                             54
#                         ],
#                         "text": "BKD.V"
#                     },
#                     {
#                         "indices": [
#                             56,
#                             62
#                         ],
#                         "text": "BKDCD"
#                     },
#                     {
#                         "indices": [
#                             103,
#                             106
#                         ],
#                         "text": "FB"
#                     }
#                 ],
#                 "hashtags": [
#                     {
#                         "indices": [
#                             0,
#                             23
#                         ],
#                         "text": "ArtificialIntelligence"
#                     },
#                     {
#                         "indices": [
#                             24,
#                             30
#                         ],
#                         "text": "Stock"
#                     },
#                     {
#                         "indices": [
#                             84,
#                             96
#                         ],
#                         "text": "GIVEMESPORT"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "url": "https://t.co/yhDWGBK04o",
#                         "indices": [
#                             116,
#                             139
#                         ],
#                         "expanded_url": "http://www.investorideas.com/CO/BKD/news/2017/05111Facebook.asp",
#                         "display_url": "investorideas.com/CO/BKD/news/20\u2026"
#                     }
#                 ],
#                 "media": [
#                     {
#                         "expanded_url": "https://twitter.com/InvestorIdeas/status/862819723318317056/photo/1",
#                         "display_url": "pic.twitter.com/ONCkcNXkdI",
#                         "url": "https://t.co/ONCkcNXkdI",
#                         "media_url_https": "https://pbs.twimg.com/media/C_lZ9u4XoAE4IwA.jpg",
#                         "id_str": "862819720709513217",
#                         "sizes": {
#                             "large": {
#                                 "h": 89,
#                                 "resize": "fit",
#                                 "w": 317
#                             },
#                             "small": {
#                                 "h": 89,
#                                 "resize": "fit",
#                                 "w": 317
#                             },
#                             "medium": {
#                                 "h": 89,
#                                 "resize": "fit",
#                                 "w": 317
#                             },
#                             "thumb": {
#                                 "h": 89,
#                                 "resize": "crop",
#                                 "w": 89
#                             }
#                         },
#                         "indices": [
#                             140,
#                             163
#                         ],
#                         "type": "photo",
#                         "id": 862819720709513217,
#                         "media_url": "http://pbs.twimg.com/media/C_lZ9u4XoAE4IwA.jpg"
#                     }
#                 ]
#             },
#             "extended_entities": {
#                 "media": [
#                     {
#                         "expanded_url": "https://twitter.com/InvestorIdeas/status/862819723318317056/photo/1",
#                         "display_url": "pic.twitter.com/ONCkcNXkdI",
#                         "url": "https://t.co/ONCkcNXkdI",
#                         "media_url_https": "https://pbs.twimg.com/media/C_lZ9u4XoAE4IwA.jpg",
#                         "id_str": "862819720709513217",
#                         "sizes": {
#                             "large": {
#                                 "h": 89,
#                                 "resize": "fit",
#                                 "w": 317
#                             },
#                             "small": {
#                                 "h": 89,
#                                 "resize": "fit",
#                                 "w": 317
#                             },
#                             "medium": {
#                                 "h": 89,
#                                 "resize": "fit",
#                                 "w": 317
#                             },
#                             "thumb": {
#                                 "h": 89,
#                                 "resize": "crop",
#                                 "w": 89
#                             }
#                         },
#                         "indices": [
#                             140,
#                             163
#                         ],
#                         "type": "photo",
#                         "id": 862819720709513217,
#                         "media_url": "http://pbs.twimg.com/media/C_lZ9u4XoAE4IwA.jpg"
#                     }
#                 ]
#             },
#             "full_text": "#ArtificialIntelligence #Stock @breakingdataco  $BKD.V; $BKDCD Records 436%+ Across #GIVEMESPORT Key ( $FB) Metrics\nhttps://t.co/yhDWGBK04o https://t.co/ONCkcNXkdI"
#         },
#         "created_at": "Fri May 12 00:00:27 +0000 2017",
#         "filter_level": "low",
#         "in_reply_to_status_id_str": null,
#         "place": null
#     },
#     "user": {
#         "follow_request_sent": null,
#         "profile_use_background_image": true,
#         "default_profile_image": false,
#         "id": 834573430234181632,
#         "verified": false,
#         "profile_image_url_https": "https://pbs.twimg.com/profile_images/838676421325148161/jfCYp5zY_normal.jpg",
#         "profile_sidebar_fill_color": "DDEEF6",
#         "profile_text_color": "333333",
#         "followers_count": 125,
#         "profile_sidebar_border_color": "C0DEED",
#         "id_str": "834573430234181632",
#         "profile_background_color": "F5F8FA",
#         "listed_count": 2,
#         "profile_background_image_url_https": "",
#         "utc_offset": null,
#         "statuses_count": 388,
#         "description": "Massachusetts has the best politicians money can buy. Investing making money.",
#         "friends_count": 19,
#         "location": "Kansas City",
#         "profile_link_color": "1DA1F2",
#         "profile_image_url": "http://pbs.twimg.com/profile_images/838676421325148161/jfCYp5zY_normal.jpg",
#         "following": null,
#         "geo_enabled": false,
#         "profile_banner_url": "https://pbs.twimg.com/profile_banners/834573430234181632/1488092914",
#         "profile_background_image_url": "",
#         "name": "Quintina",
#         "lang": "en",
#         "profile_background_tile": false,
#         "favourites_count": 26,
#         "screen_name": "aM3eWRltqzRoapT",
#         "notifications": null,
#         "url": null,
#         "created_at": "Thu Feb 23 01:19:46 +0000 2017",
#         "contributors_enabled": false,
#         "time_zone": null,
#         "protected": false,
#         "default_profile": true,
#         "is_translator": false
#     },
#     "geo": null,
#     "in_reply_to_user_id_str": null,
#     "lang": "en",
#     "created_at": "Fri May 12 11:36:04 +0000 2017",
#     "filter_level": "low",
#     "in_reply_to_status_id_str": null,
#     "place": null
# }

# %%
import re
 
emoticons_str = r"""
    (?:
        [:=;] # Eyes
        [oO\-]? # Nose (optional)
        [D\)\]\(\]/\\OpP] # Mouth
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
    
tokens_re = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE)
emoticon_re = re.compile(r'^'+emoticons_str+'$', re.VERBOSE | re.IGNORECASE)
 
def tokenize(s):
    return tokens_re.findall(s)
 
def preprocess(s, lowercase=False):
    tokens = tokenize(s)
    if lowercase:
        tokens = [token if emoticon_re.search(token) else token.lower() for token in tokens]
    return tokens

# %%
with open('ArtificialIntelligenceTweets.json', 'r') as f:
#import io
#f=io.open('data/stream_barcelona.json', 'r', encoding='utf8' )
     for line in f:
        tweet = json.loads(line)
        tokens = preprocess(tweet['text'])
        print(tokens)
# Out:
# [u'RT', u'@InvestorIdeas', u':', u'#ArtificialIntelligence', u'#Stock', u'@breakingdataco', u'$', u'BKD', u'.', u'V', u';', u'$', u'BKDCD', u'Records', u'436', u'%', u'+', u'Across', u'#GIVEMESPORT', u'Key', u'(', u'$', u'FB', u')', u'Metrics', u'\u2026']
# [u'RT', u'@IBMItalia', u':', u'Al', u'#WatsonSummit2017', u'@RICOHItalia', u'ci', u'mostrer', u'\xe0', u'come', u'l', u"'", u'#ArtificialIntelligence', u'pu', u'\xf2', u'trasformare', u'i', u'meeting', u'aziendali', u'https://t.', u'\u2026']
# [u'How', u'media', u'agency', u'#Maxus', u'is', u'testing', u'#ArtificialIntelligence', u'.', u'#machinelearning', u'#deeplearning', u'https://t.co/fQHoDtMnXb']
# [u'Brazils', u'#banks', u'turn', u'to', u'#AI', u'eye', u'blockchain', u'https://t.co/tXn2LSvYBi', u'#Blockchain', u'#Tech', u'#TechNews', u'#ArtificialIntelligence', u'#BankTech', u'#Brazil']
# [u'#Artificialintelligence', u'emerging', u'as', u'a', u'force', u'for', u'good', u'https://t.co/RrPCrkDZEL']
# [u'RT', u'@InvestorIdeas', u':', u'#Technology', u'#Stocks', u':', u'#ArtificialIntelligence', u'-', u'Opportunity', u'&', u'amp', u';', u'#Market', u';', u'(', u'$', u'EA', u')', u',', u'(', u'$', u'GOOGL', u')', u',', u'(', u'$', u'GOPH', u')', u',', u'(', u'$', u'FB', u')', u',', u'(', u'$', u'IBM', u')', u'http', u'\u2026']

# %%
import operator 
import json
from collections import Counter

fname = 'ArtificialIntelligenceTweets.json'
with open(fname, 'r') as f:
   count_all = Counter()
   for line in f:
       tweet = json.loads(line)
       # Create a list with all the terms
       terms_all = [term for term in preprocess(tweet['text'])]
       # Update the counter
       count_all.update(terms_all)
   print(count_all.most_common(5))
# Out:
# [(u'$', 8), (u')', 6), (u'(', 6), (u'#ArtificialIntelligence', 5), (u':', 4)]

# %%
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords") # download the stopword corpus on our computer
import string
 
punctuation = list(string.punctuation)
stop = stopwords.words('english') + punctuation + ['rt', 'via', 'RT']
# Out:
# [nltk_data] Downloading package stopwords to /home/chetan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import operator 
import json
from collections import Counter
 
fname = 'ArtificialIntelligenceTweets.json'
with open(fname, 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        # Create a list with all the terms
        terms_stop = [term for term in preprocess(tweet['text']) if term not in stop]
        count_all.update(terms_stop)
    for word, index in count_all.most_common(5):
        print '%s : %s' % (word, index)
# Out:
# #ArtificialIntelligence : 5
# … : 3
# @InvestorIdeas : 2
# FB : 2
# ci : 1

# %%
terms_hash = [term for term in preprocess(tweet['text']) 
              if term.startswith('#')]

# %%
terms_only = [term for term in preprocess(tweet['text']) 
              if term not in stop and
              not term.startswith(('#', '@'))]

# %%
import operator 
import json
from collections import Counter
 
fname = 'ArtificialIntelligenceTweets.json'
with open(fname, 'r') as f:
    count_all = Counter()
    for line in f:
        tweet = json.loads(line)
        # Create a list with all the terms
        terms_hash = [term for term in preprocess(tweet['text']) if term.startswith('#') and term not in stop]        
        count_all.update(terms_hash)
# Print the first 10 most frequent words
print(count_all.most_common(15))
# Out:
# [(u'#ArtificialIntelligence', 5), (u'#Tech', 1), (u'#Blockchain', 1), (u'#GIVEMESPORT', 1), (u'#Brazil', 1), (u'#deeplearning', 1), (u'#Technology', 1), (u'#BankTech', 1), (u'#TechNews', 1), (u'#Stock', 1), (u'#WatsonSummit2017', 1), (u'#Maxus', 1), (u'#AI', 1), (u'#Stocks', 1), (u'#banks', 1)]

# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (15,10)
import matplotlib.pyplot as plt

sorted_x, sorted_y = zip(*count_all.most_common(15))
#print(sorted_x, sorted_y)

plt.bar(range(len(sorted_x)), sorted_y, width=0.75, align='center');
plt.xticks(range(len(sorted_x)), sorted_x, rotation=80);
plt.axis('tight');
